# %%
from keras.datasets import mnist
data=mnist.load_data()
type(data)
# Out:
# tuple

# %%
(X_train,y_train),(X_test,y_test)=data

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train=X_train.reshape((X_train.shape[0],28*28)).astype('float32')
X_test=X_test.reshape((X_test.shape[0],28*28)).astype('float32')

# %%
X_train=X_train/255
X_test=X_test/255

# %%
from keras.utils import np_utils
y_train=np_utils.to_categorical(y_train)
y_test=np_utils.to_categorical(y_test)
num_classes=y_test.shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
model=Sequential()
model.add(Dense(32, input_dim=28*28, activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.7730 - accuracy: 0.7858
# Epoch 2/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2134 - accuracy: 0.9377
# Epoch 3/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1630 - accuracy: 0.9527
# Epoch 4/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1387 - accuracy: 0.9598
# Epoch 5/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1179 - accuracy: 0.9650
# Epoch 6/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1047 - accuracy: 0.9681
# Epoch 7/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0932 - accuracy: 0.9730
# Epoch 8/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0856 - accuracy: 0.9751
# Epoch 9/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0778 - accuracy: 0.9765
# Epoch 10/10
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0720 - accuracy: 0.9782

# %%
scores=model.evaluate(X_test,y_test)
print(scores)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1085 - accuracy: 0.9676
# [0.10853354632854462, 0.9675999879837036]
